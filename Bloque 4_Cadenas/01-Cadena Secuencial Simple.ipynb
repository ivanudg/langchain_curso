# %% [markdown]
# <em style="text-align:center">Copyright Iván Pinar Domínguez</em>

# %% [markdown]
# ## Importar librerías e instancia de modelo de chat

# %%
from langchain_core.prompts import PromptTemplate, SystemMessagePromptTemplate,ChatPromptTemplate, HumanMessagePromptTemplate
from langchain_openai import ChatOpenAI
f = open('../OpenAI_key.txt')
api_key = f.read()
chat = ChatOpenAI(openai_api_key=api_key)

# %% [markdown]
# ##  Creación objeto LLMChain

# %%
human_message_prompt = HumanMessagePromptTemplate.from_template(
        "Dame un nombre de compañía que sea simpático para una compañía que fabrique {producto}"
    )

# %%
chat_prompt_template = ChatPromptTemplate.from_messages([human_message_prompt])

# %%
from langchain_classic.chains import LLMChain #instalar con: pip install -U langchain-classic
chain = LLMChain(llm=chat, prompt=chat_prompt_template)
# Out:
# C:\Users\Iván Pinar\AppData\Local\Temp\ipykernel_9632\1083906179.py:2: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use `RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(llm=chat, prompt=chat_prompt_template)

# %%
print(chain.invoke(input="Lavadoras"))
# Out:
# {'producto': 'Lavadoras', 'text': '"Burbuja Wash"'}

# %% [markdown]
# #  Cadena Secuencia Simple

# %%
from langchain_classic.chains.sequential import SimpleSequentialChain

# %%
llm = ChatOpenAI(openai_api_key=api_key)

# %%
template = "Dame un simple resumen con un listado de puntos para un post de un blog acerca de {tema}"
prompt1 = ChatPromptTemplate.from_template(template)
chain_1 = LLMChain(llm=llm,prompt=prompt1)

# %%
template = "Escribe un post completo usando este resumen: {resumen}"
prompt2 = ChatPromptTemplate.from_template(template)
chain_2 = LLMChain(llm=llm,prompt=prompt2)

# %%
full_chain = SimpleSequentialChain(chains=[chain_1,chain_2],
                                  verbose=True) #verbose=True nos irá dando paso a paso lo que hace, pudiendo ver los resultados intermedios

# %%
result = full_chain.invoke(input="Inteligencia Artificial")
# Out:
# > Entering new SimpleSequentialChain chain...
# - Introducción a la Inteligencia Artificial
# - Definición y concepto de IA
# - Breve historia de la IA
# - Aplicaciones prácticas de la IA en la actualidad
# - Beneficios y riesgos de la IA
# - Futuro de la Inteligencia Artificial
# - Conclusiones finales
# En la actualidad, la Inteligencia Artificial (IA) se ha convertido en una de las tecnologías más relevantes y disruptivas en diversos sectores de la sociedad. Desde la medicina hasta el comercio, pasando por la industria automotriz y la logística, la IA ha demostrado ser una herramienta poderosa que puede mejorar la eficiencia, la automatización y la toma de decisiones de manera significativa.
#
# Pero, ¿qué es exactamente la Inteligencia Artificial? La IA se refiere a la capacidad de las máquinas para aprender, razonar y tomar decisiones de manera similar a la humana. A través de algoritmos y datos, las máquinas pueden procesar información y realizar tareas con un alto grado de precisión y eficiencia.
#
# La historia de la IA se remonta a mediados del siglo XX, cuando científicos como Alan Turing y John McCarthy sentaron las bases teóricas de esta disciplina. En las décadas siguientes, la IA experimentó avances significativos, impulsados por el aumento de la capacidad computacional y el desarrollo de algoritmos más sofisticados.
#
# En la actualidad, la IA se utiliza en una amplia gama de aplicaciones prácticas. Desde los asistentes virtuales como Siri y Alexa, hasta los sistemas de recomendación en plataformas como Netflix y Amazon, la IA ha demostrado su utilidad en la optimización de procesos y la personalización de servicios.
#
# No obstante, la IA también plantea desafíos y riesgos importantes. Entre los beneficios de la IA se encuentran la mejora de la productividad, la reducción de costos y la optimización de los resultados. Sin embargo, existen preocupaciones en torno a la privacidad de los datos, la discriminación algorítmica y la pérdida de puestos de trabajo debido a la automatización.
#
# En cuanto al futuro de la Inteligencia Artificial, se espera que continúe evolucionando y expandiéndose a nuevos sectores y aplicaciones. Con el avance de la tecnología y la creciente disponibilidad de datos, la IA promete seguir mejorando la calidad de vida de las personas y transformando la forma en que operan las organizaciones.
#
# En conclusión, la Inteligencia Artificial es una tecnología poderosa que tiene el potencial de revolucionar múltiples aspectos de nuestra sociedad. Si se utiliza de manera ética y responsable, la IA puede traer importantes beneficios y mejoras en nuestras vidas. Sin embargo, es fundamental abordar los riesgos y desafíos asociados a su implementación, para garantizar un uso seguro y equitativo de esta tecnología innovadora.
#
# > Finished chain.

# %%
print(result['output'])
# Out:
# En la actualidad, la Inteligencia Artificial (IA) se ha convertido en una de las tecnologías más relevantes y disruptivas en diversos sectores de la sociedad. Desde la medicina hasta el comercio, pasando por la industria automotriz y la logística, la IA ha demostrado ser una herramienta poderosa que puede mejorar la eficiencia, la automatización y la toma de decisiones de manera significativa.
#
# Pero, ¿qué es exactamente la Inteligencia Artificial? La IA se refiere a la capacidad de las máquinas para aprender, razonar y tomar decisiones de manera similar a la humana. A través de algoritmos y datos, las máquinas pueden procesar información y realizar tareas con un alto grado de precisión y eficiencia.
#
# La historia de la IA se remonta a mediados del siglo XX, cuando científicos como Alan Turing y John McCarthy sentaron las bases teóricas de esta disciplina. En las décadas siguientes, la IA experimentó avances significativos, impulsados por el aumento de la capacidad computacional y el desarrollo de algoritmos más sofisticados.
#
# En la actualidad, la IA se utiliza en una amplia gama de aplicaciones prácticas. Desde los asistentes virtuales como Siri y Alexa, hasta los sistemas de recomendación en plataformas como Netflix y Amazon, la IA ha demostrado su utilidad en la optimización de procesos y la personalización de servicios.
#
# No obstante, la IA también plantea desafíos y riesgos importantes. Entre los beneficios de la IA se encuentran la mejora de la productividad, la reducción de costos y la optimización de los resultados. Sin embargo, existen preocupaciones en torno a la privacidad de los datos, la discriminación algorítmica y la pérdida de puestos de trabajo debido a la automatización.
#
# En cuanto al futuro de la Inteligencia Artificial, se espera que continúe evolucionando y expandiéndose a nuevos sectores y aplicaciones. Con el avance de la tecnología y la creciente disponibilidad de datos, la IA promete seguir mejorando la calidad de vida de las personas y transformando la forma en que operan las organizaciones.
#
# En conclusión, la Inteligencia Artificial es una tecnología poderosa que tiene el potencial de revolucionar múltiples aspectos de nuestra sociedad. Si se utiliza de manera ética y responsable, la IA puede traer importantes beneficios y mejoras en nuestras vidas. Sin embargo, es fundamental abordar los riesgos y desafíos asociados a su implementación, para garantizar un uso seguro y equitativo de esta tecnología innovadora.
