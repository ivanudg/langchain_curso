# %% [markdown]
# <em style="text-align:center">Copyright Iván Pinar Domínguez</em>

# %% [markdown]
# ## Importar librerías de templates

# %%
from langchain_core.prompts import (
    ChatPromptTemplate,
    PromptTemplate,
    SystemMessagePromptTemplate,
    AIMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
from langchain_core.messages import (
    AIMessage,
    HumanMessage,
    SystemMessage
)
# Out:
# /Users/jorgeivanuribemejia/Library/CloudStorage/OneDrive-Indra/Cursos/LangChain_LLMs/Proyectos/.venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %% [markdown]
# ## Generar plantillas de prompts

# %%
#Creamos la plantilla del sistema (system_template)
system_template="Eres una IA especializada en coches de tipo {tipo_coches} y generar artículos que se leen en {tiempo_lectura}."
system_message_prompt = SystemMessagePromptTemplate.from_template(system_template)

# %%
system_message_prompt.input_variables
# Out:
# ['tiempo_lectura', 'tipo_coches']

# %%
#Creamos la plantilla de usuario (human_template)
human_template="Necesito un artículo para vehículos con motor {peticion_tipo_motor}"
human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)

# %%
human_message_prompt.input_variables
# Out:
# ['peticion_tipo_motor']

# %%
#Creamos una plantilla de chat con la concatenación tanto de mensajes del sistema como del humano
chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, human_message_prompt])

# %%
chat_prompt.input_variables
# Out:
# ['peticion_tipo_motor', 'tiempo_lectura', 'tipo_coches']

# %%
# Completar el chat gracias al formateo de los mensajes
chat_prompt.format_prompt(peticion_tipo_motor="híbrido enchufable", tiempo_lectura="10 min", tipo_coches="Japoneses")
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Eres una IA especializada en coches de tipo Japoneses y generar artículos que se leen en 10 min.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Necesito un artículo para vehículos con motor híbrido enchufable', additional_kwargs={}, response_metadata={})])

# %%
#Transformamos el objeto prompt a una lista de mensajes y lo guardamos en "solicitud_completa" que es lo que pasaremos al LLM finalmente
solicitud_completa = chat_prompt.format_prompt(peticion_tipo_motor="híbrido enchufable", tiempo_lectura="10 min", tipo_coches="japoneses").to_messages()

# %% [markdown]
# ## Obtener el resultado de la respuesta formateada

# %%
from langchain_openai import ChatOpenAI

# %%
f = open('../OpenAI_key.txt')
api_key = f.read()
chat = ChatOpenAI(openai_api_key=api_key)

# %%
result = chat.invoke(solicitud_completa)

# %%
result
# Out:
# AIMessage(content='**Los vehículos con motor híbrido enchufable: el futuro de la movilidad sostenible**\n\nLos vehículos con motor híbrido enchufable han ido ganando popularidad en los últimos años como una alternativa más sostenible y eficiente a los vehículos tradicionales. Estos automóviles combinan un motor de combustión interna con uno eléctrico, lo que les permite reducir las emisiones de gases contaminantes y disminuir el consumo de combustible. En este artículo, exploraremos en detalle qué son los vehículos con motor híbrido enchufable, sus ventajas y desventajas, así como algunos ejemplos de modelos disponibles en el mercado japonés.\n\n**¿Qué es un vehículo con motor híbrido enchufable?**\n\nUn vehículo con motor híbrido enchufable, también conocido como PHEV por sus siglas en inglés (Plug-in Hybrid Electric Vehicle), es un automóvil que combina un motor de combustión interna con al menos un motor eléctrico y una batería recargable desde una toma de corriente externa. Estos vehículos pueden funcionar tanto con electricidad como con combustible, lo que les otorga una mayor autonomía y flexibilidad en comparación con los vehículos híbridos convencionales.\n\n**Ventajas de los vehículos con motor híbrido enchufable**\n\n- **Menor impacto ambiental**: al poder funcionar con electricidad, los vehículos con motor híbrido enchufable emiten menos gases contaminantes y contribuyen a reducir la huella de carbono.\n  \n- **Ahorro de combustible**: al aprovechar la energía eléctrica para desplazarse en distancias cortas, estos vehículos reducen significativamente el consumo de combustible y, por ende, los costos de operación.\n\n- **Mayor autonomía**: gracias a la combinación de un motor eléctrico y uno de combustión interna, los vehículos híbridos enchufables ofrecen una mayor autonomía que los vehículos eléctricos puros.\n\n- **Incentivos fiscales**: en muchos países, los propietarios de vehículos con motor híbrido enchufable pueden beneficiarse de incentivos fiscales y tarifas reducidas, lo que los hace más atractivos desde el punto de vista económico.\n\n**Desventajas de los vehículos con motor híbrido enchufable**\n\n- **Costo inicial más alto**: debido a la tecnología avanzada que incorporan, los vehículos con motor híbrido enchufable suelen tener un costo inicial más elevado que los vehículos tradicionales.\n\n- **Menor espacio de carga**: la presencia de la batería suele reducir el espacio disponible en el maletero, lo que puede limitar la capacidad de carga del vehículo.\n\n- **Infraestructura de carga**: si bien es posible recargar la batería de un vehículo híbrido enchufable en casa, es necesario contar con una infraestructura de carga adecuada para garantizar su uso óptimo.\n\n**Ejemplos de vehículos con motor híbrido enchufable disponibles en Japón**\n\n- **Toyota Prius Prime**: este icónico modelo de Toyota cuenta con un motor híbrido enchufable que le permite recorrer hasta 40 km en modo eléctrico puro y una autonomía total de más de 1,000 km.\n\n- **Mitsubishi Outlander PHEV**: este SUV híbrido enchufable combina un potente motor de combustión interna con dos motores eléctricos, ofreciendo un rendimiento excepcional tanto en carretera como fuera de ella.\n\n- **Nissan Leaf e+:** la versión enchufable del popular Nissan Leaf incorpora un sistema híbrido que le otorga una autonomía extendida y un rendimiento superior en comparación con la versión eléctrica convencional.\n\nEn conclusión, los vehículos con motor híbrido enchufable representan una opción atractiva para aquellos que buscan reducir su impacto ambiental sin renunciar a la comodidad y el rendimiento de un automóvil convencional. Con una creciente variedad de modelos disponibles en el mercado japonés, es posible encontrar el vehículo híbrido enchufable que mejor se adapte a tus necesidades y preferencias. ¡Invierte en un futuro más sostenible con los vehículos híbridos enchufables!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': { ...

# %%
print(result.content)
# Out:
# **Los vehículos con motor híbrido enchufable: el futuro de la movilidad sostenible**
#
# Los vehículos con motor híbrido enchufable han ido ganando popularidad en los últimos años como una alternativa más sostenible y eficiente a los vehículos tradicionales. Estos automóviles combinan un motor de combustión interna con uno eléctrico, lo que les permite reducir las emisiones de gases contaminantes y disminuir el consumo de combustible. En este artículo, exploraremos en detalle qué son los vehículos con motor híbrido enchufable, sus ventajas y desventajas, así como algunos ejemplos de modelos disponibles en el mercado japonés.
#
# **¿Qué es un vehículo con motor híbrido enchufable?**
#
# Un vehículo con motor híbrido enchufable, también conocido como PHEV por sus siglas en inglés (Plug-in Hybrid Electric Vehicle), es un automóvil que combina un motor de combustión interna con al menos un motor eléctrico y una batería recargable desde una toma de corriente externa. Estos vehículos pueden funcionar tanto con electricidad como con combustible, lo que les otorga una mayor autonomía y flexibilidad en comparación con los vehículos híbridos convencionales.
#
# **Ventajas de los vehículos con motor híbrido enchufable**
#
# - **Menor impacto ambiental**: al poder funcionar con electricidad, los vehículos con motor híbrido enchufable emiten menos gases contaminantes y contribuyen a reducir la huella de carbono.
#
# - **Ahorro de combustible**: al aprovechar la energía eléctrica para desplazarse en distancias cortas, estos vehículos reducen significativamente el consumo de combustible y, por ende, los costos de operación.
#
# - **Mayor autonomía**: gracias a la combinación de un motor eléctrico y uno de combustión interna, los vehículos híbridos enchufables ofrecen una mayor autonomía que los vehículos eléctricos puros.
#
# - **Incentivos fiscales**: en muchos países, los propietarios de vehículos con motor híbrido enchufable pueden beneficiarse de incentivos fiscales y tarifas reducidas, lo que los hace más atractivos desde el punto de vista económico.
#
# **Desventajas de los vehículos con motor híbrido enchufable**
#
# - **Costo inicial más alto**: debido a la tecnología avanzada que incorporan, los vehículos con motor híbrido enchufable suelen tener un costo inicial más elevado que los vehículos tradicionales.
#
# - **Menor espacio de carga**: la presencia de la batería suele reducir el espacio disponible en el maletero, lo que puede limitar la capacidad de carga del vehículo.
#
# - **Infraestructura de carga**: si bien es posible recargar la batería de un vehículo híbrido enchufable en casa, es necesario contar con una infraestructura de carga adecuada para garantizar su uso óptimo.
#
# **Ejemplos de vehículos con motor híbrido enchufable disponibles en Japón**
#
# - **Toyota Prius Prime**: este icónico modelo de Toyota cuenta con un motor híbrido enchufable que le permite recorrer hasta 40 km en modo eléctrico puro y una autonomía total de más de 1,000 km.
#
# - **Mitsubishi Outlander PHEV**: este SUV híbrido enchufable combina un potente motor de combustión interna con dos motores eléctricos, ofreciendo un rendimiento excepcional tanto en carretera como fuera de ella.
#
# - **Nissan Leaf e+:** la versión enchufable del popular Nissan Leaf incorpora un sistema híbrido que le otorga una autonomía extendida y un rendimiento superior en comparación con la versión eléctrica convencional.
#
# En conclusión, los vehículos con motor híbrido enchufable representan una opción atractiva para aquellos que buscan reducir su impacto ambiental sin renunciar a la comodidad y el rendimiento de un automóvil convencional. Con una creciente variedad de modelos disponibles en el mercado japonés, es posible encontrar el vehículo híbrido enchufable que mejor se adapte a tus necesidades y preferencias. ¡Invierte en un futuro más sostenible con los vehículos híbridos enchufables!
