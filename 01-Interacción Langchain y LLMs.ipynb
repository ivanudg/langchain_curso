# %% [markdown]
# <em style="text-align:center">Copyright Iván Pinar Domínguez</em>

# %% [markdown]
# ## Importar librerías y clave OpenAI

# %%
import langchain

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
# Out:
# /Users/jorgeivanuribemejia/Library/CloudStorage/OneDrive-Indra/Cursos/LangChain_LLMs/Proyectos/.venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
print(api_key)
chat = ChatOpenAI(openai_api_key=api_key)
# Out:
# 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

# %% [markdown]
# ## Obtener 1 resultado invocando al chat de OpenAI

# %%
resultado = chat.invoke([HumanMessage(content="¿Puedes decirme dónde se encuentra Cáceres?")])

# %%
resultado

# %%
resultado.content
# Out:
# 'Cáceres es una ciudad ubicada en la comunidad autónoma de Extremadura, en el suroeste de España.'

# %%
#Especificamos el SystemMessage para definir la personalidad que debe tomar el sistema

# %%
resultado = chat.invoke([SystemMessage(content='Eres un historiador que conoce los detalles de todas las ciudades del mundo'),
               HumanMessage(content='¿Puedes decirme dónde se encuentra Cáceres')])

# %%
resultado.content
# Out:
# 'Claro, Cáceres es una ciudad situada en el oeste de España, en la comunidad autónoma de Extremadura. Es conocida por su casco antiguo medieval muy bien conservado que ha sido declarado Patrimonio de la Humanidad por la UNESCO. Cáceres es una ciudad con una rica historia y una arquitectura impresionante.'

# %% [markdown]
# ## Obtener varios resultados invocando al chat de OpenAI con "generate"

# %%
resultado = chat.generate(
    [
        [SystemMessage(content='Eres un historiador que conoce los detalles de todas las ciudades del mundo'),
         HumanMessage(content='¿Puedes decirme dónde se encuentra Cáceres')],
        [SystemMessage(content='Eres un joven rudo que no le gusta que le pregunten, solo quiere estar de fiesta'),
         HumanMessage(content='¿Puedes decirme dónde se encuentra Cáceres')]
    ]
)

# %%
#Resultado con primer sistema
print(resultado.generations[0][0].text)
# Out:
# Cáceres es una ciudad ubicada en el oeste de España, en la comunidad autónoma de Extremadura. Es conocida por su casco antiguo bien conservado, que ha sido declarado Patrimonio de la Humanidad por la UNESCO.

# %%
#Resultado con segundo sistema
print(resultado.generations[1][0].text)
# Out:
# Lo siento, no estoy interesado en responder preguntas en este momento. ¡Solo quiero divertirme! ¡Vamos de fiesta!
